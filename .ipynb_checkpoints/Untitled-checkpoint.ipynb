# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
new_data = pd.read_csv('dengue_data.csv')

# %%
new_data
# Out:
#     Province      Districts  Jan  Feb  Mar  Apr  May  Jun  Jul   Aug  Sept  \
# 0          3  306 KATHMANDU    0    0    0    0    1    1   35   727  9891
# 1          3   308 LALITPUR    0    0    0    0    0    1   99  1558  6016
# 2          3  307 BHAKTAPUR    0    0    0    0    0    0    6    86  1151
# 3          3  312 MAKWANPUR    0    0    0    0    0    0  221   337  2452
# 4          3   313 CHITAWAN    0    0    0    0    0    3    4    24   995
# ..       ...            ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 72         6        602MUGU    0    0    0    0    0    0    0     1     7
# 73         3     303 RASUWA    0    0    0    0    0    0    0     0     6
# 74         4    403 MUSTANG    0    0    0    0    0    0    0     0     2
# 75         6      601 DOLPA    0    0    0    0    0    0    0     1     1
# 76         6      603 HUMLA    0    0    0    0    0    0    0     0     2
#
#      Oct  Nov  Dec  Grand Total
# 0   2911  761   49        14376
# 1   1809  120   11         9614
# 2   4204  677   21         6145
# 3   2220  590   17         5837
# 4   1509  638   40         3213
# ..   ...  ...  ...          ...
# 72     4    0    0           12
# 73     5    0    0           11
# 74     6    0    0            8
# 75     2    1    0            5
# 76     1    0    0            3
#
# [77 rows x 15 columns]

# %%
# new_data

# %%
# new_data['Province'].unique()

# %%
# new_data['Jan'].count()

# %%
# new_data.sum()

# %%
def remove_int(x):
    return ''.join(filter(str.isalpha, x))

# %%
new_data['Districts']=new_data['Districts'].apply(remove_int)

# %%
new_data['Districts']
# Out:
# 0     KATHMANDU
# 1      LALITPUR
# 2     BHAKTAPUR
# 3     MAKWANPUR
# 4      CHITAWAN
#         ...
# 72         MUGU
# 73       RASUWA
# 74      MUSTANG
# 75        DOLPA
# 76        HUMLA
# Name: Districts, Length: 77, dtype: object

# %%
new_data.head()
# Out:
#    Province  Districts  Jan  Feb  Mar  Apr  May  Jun  Jul   Aug  Sept   Oct  \
# 0         3  KATHMANDU    0    0    0    0    1    1   35   727  9891  2911
# 1         3   LALITPUR    0    0    0    0    0    1   99  1558  6016  1809
# 2         3  BHAKTAPUR    0    0    0    0    0    0    6    86  1151  4204
# 3         3  MAKWANPUR    0    0    0    0    0    0  221   337  2452  2220
# 4         3   CHITAWAN    0    0    0    0    0    3    4    24   995  1509
#
#    Nov  Dec  Grand Total
# 0  761   49        14376
# 1  120   11         9614
# 2  677   21         6145
# 3  590   17         5837
# 4  638   40         3213

# %%
# x_labels = list(new_data.columns[2:])
# x_labels

# %%
# y_labels=new_data[]

# %%
# y_labels

# %%
# plt.bar(x_labels,y_labels)

# %%
x=new_data['Districts'].tolist()

# %%
y= [y for y in data['Grand Total'].tolist() if y >= 1682]
temp=[y for y in data['Grand Total'].tolist() if y < 1682]
y.append(sum(temp))
x = new_data.loc[new_data['Grand Total'].isin(y)]['Districts'].tolist()
x.append('Others')

# %%
x
# Out:
# ['KATHMANDU',
#  'LALITPUR',
#  'BHAKTAPUR',
#  'MAKWANPUR',
#  'CHITAWAN',
#  'DANG',
#  'DHADING',
#  'Others']

# %%
plt.pie(y,labels=x)
plt.show()

# %%
x1=new_data.loc[:,'Jan':'Dec'].sum().tolist()
x1
# Out:
# [11, 3, 15, 18, 25, 93, 720, 3708, 27529, 17889, 4290, 483]

# %%
y1=list(new_data.columns)[2:-1]
y1
# Out:
# ['Jan',
#  'Feb',
#  'Mar',
#  'Apr',
#  'May',
#  'Jun',
#  'Jul',
#  'Aug',
#  'Sept',
#  'Oct',
#  'Nov',
#  'Dec']

# %%
plt.bar(y1,x1)
plt.show()

# %%
new_data.loc[:,'Jan':'Dec'].describe()
# Out:
#              Jan        Feb        Mar        Apr        May        Jun  \
# count  77.000000  77.000000  77.000000  77.000000  77.000000  77.000000
# mean    0.142857   0.038961   0.194805   0.233766   0.324675   1.207792
# std     0.420347   0.194771   0.858992   0.666809   0.865137   3.931444
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 50%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 75%     0.000000   0.000000   0.000000   0.000000   0.000000   1.000000
# max     2.000000   1.000000   7.000000   4.000000   6.000000  32.000000
#
#               Jul          Aug         Sept          Oct         Nov  \
# count   77.000000    77.000000    77.000000    77.000000   77.000000
# mean     9.350649    48.155844   357.519481   232.324675   55.714286
# std     30.038469   199.277977  1340.169762   667.530158  152.060485
# min      0.000000     0.000000     1.000000     0.000000    0.000000
# 25%      0.000000     2.000000    23.000000     7.000000    3.000000
# 50%      2.000000     5.000000    54.000000    37.000000   12.000000
# 75%      5.000000    14.000000    87.000000   105.000000   30.000000
# max    221.000000  1558.000000  9891.000000  4204.000000  761.000000
#
#              Dec
# count  77.000000
# mean    6.272727
# std     9.824294
# min     0.000000
# 25%     0.000000
# 50%     2.000000
# 75%     9.000000
# max    49.000000

# %%
map_data=pd.read_json('map_data.json')
map_data
# Out:
#     district  longitude  latitude
# 0  KATHMANDU    85.3045   27.7172
# 1   LALITPUR    85.3176   27.6679
# 2  BHAKTAPUR    85.4280   27.6717
# 3  MAKWANPUR    85.2014   27.4869
# 4   CHITAWAN    84.2555   27.6190
# 5       DANG    82.3915   28.1167
# 6    DHADING    84.9582   27.9779

# %%
import folium

# %%
locations = map_data[['latitude', 'longitude']]
