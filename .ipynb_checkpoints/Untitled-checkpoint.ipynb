# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
new_data = pd.read_csv('dengue_data.csv')

# %%
new_data
# Out:
#       Province     Districts  Jan  Feb  Mar  Apr  May  Jun   Jul    Aug  \
# 0            3  306KATHMANDU    0    0    0    0    1    1    35    727
# 1            3   308LALITPUR    0    0    0    0    0    1    99   1558
# 2            3  307BHAKTAPUR    0    0    0    0    0    0     6     86
# 3            3  312MAKWANPUR    0    0    0    0    0    0   221    337
# 4            3   313CHITAWAN    0    0    0    0    0    3     4     24
# ..         ...           ...  ...  ...  ...  ...  ...  ...   ...    ...
# 73           3     303RASUWA    0    0    0    0    0    0     0      0
# 74           4    403MUSTANG    0    0    0    0    0    0     0      0
# 75           6      601DOLPA    0    0    0    0    0    0     0      1
# 76           6      603HUMLA    0    0    0    0    0    0     0      0
# 77  GrandTotal            11    3   15   18   25   93  720  3708  27529
#
#      Sept   Oct  Nov    Dec  Grand Total
# 0    9891  2911  761     49      14376.0
# ...

# %%
def remove_int(x):
    return ''.join(filter(str.isalpha, x))

# %%
new_data['Districts']=new_data['Districts'].apply(remove_int)

# %%
new_data['Districts']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Districts'
#
# ...

# %%
new_data.head()
# Out:
#   Province     Districts  Jan  Feb  Mar  Apr  May  Jun  Jul   Aug  Sept   Oct  \
# 0        3  306KATHMANDU    0    0    0    0    1    1   35   727  9891  2911
# 1        3   308LALITPUR    0    0    0    0    0    1   99  1558  6016  1809
# 2        3  307BHAKTAPUR    0    0    0    0    0    0    6    86  1151  4204
# 3        3  312MAKWANPUR    0    0    0    0    0    0  221   337  2452  2220
# 4        3   313CHITAWAN    0    0    0    0    0    3    4    24   995  1509
#
#    Nov  Dec  Grand Total
# 0  761   49      14376.0
# 1  120   11       9614.0
# 2  677   21       6145.0
# 3  590   17       5837.0
# 4  638   40       3213.0

# %%
x=new_data['Districts'].tolist()
x
# Out:
# ['306KATHMANDU',
#  '308LALITPUR',
#  '307BHAKTAPUR',
#  '312MAKWANPUR',
#  '313CHITAWAN',
#  '510DANG',
#  '304DHADING',
#  '508RUPANDEHI',
#  '309KAVREPALANCHOK',
#  '610SURKHET',
#  '708KAILALI',
#  '113SUNSARI',
#  '407TANAHU',
#  '703DARCHULA',
#  '207BARA',
#  '102SANKHUWASABHA',
#  '504GULMI',
#  '401GORKHA',
#  '105KHOTANG',
#  '410PARBAT',
#  '305NUWAKOT',
#  '709KANCHANPUR',
#  '405KASKI',
#  '111JHAPA',
#  '310RAMECHHAP',
#  '302SINDHUPALCHOK',
#  '409SYANGJA',
#  '512BARDIYA',
#  '208PARSA',
#  '506PALPA',
#  '411BAGLUNG',
#  '112MORANG',
#  '408NAWALPARASI EAST',
#  '108TERHATHUM',
#  '311SINDHULI',
#  '505ARGHAKHANCHI',
#  '511BANKE',
#  '205SARLAHI',
#  '114UDAYAPUR',
#  '107DHANKUTA',
#  '206RAUTAHAT',
#  '509KAPILBASTU',
#  '507NAWALPARASI WEST',
#  '110ILAM',
#  '106BHOJPUR',
#  '301DOLAKHA',
#  '406LAMJUNG',
#  '706DOTI',
#  '109PANCHTHAR',
#  '704BAITADI',
#  '404MYAGDI',
#  '204MAHOTTARI',
#  '104OKHALDHUNGA',
#  '503PYUTHAN',
#  '608RUKUM WEST',
# ...

# %%
y= [y for y in new_data['Grand Total'].tolist() if y >= 1682]
temp=[y for y in new_data['Grand Total'].tolist() if y < 1682]
y.append(sum(temp))
x = new_data.loc[new_data['Grand Total'].isin(y)]['Districts'].tolist()
x.append('Others')

# %%
x
# Out:
# ['306KATHMANDU',
#  '308LALITPUR',
#  '307BHAKTAPUR',
#  '312MAKWANPUR',
#  '313CHITAWAN',
#  '510DANG',
#  '304DHADING',
#  'Others']

# %%
new_data.loc[new_data['Districts'].isin(x)]['Province'].tolist()
# Out:
# ['3', '3', '3', '3', '3', '5', '3']

# %%
plt.pie(y,labels=x)
plt.show()

# %%
x1=new_data.loc[:,'Jan':'Dec'].sum().tolist()
x1
# Out:
# [11, 3, 15, 18, 25, 93, 720, 3708, 27529, 17889, 4290, 483]

# %%
y1=list(new_data.columns)[2:-1]
y1
# Out:
# ['Jan',
#  'Feb',
#  'Mar',
#  'Apr',
#  'May',
#  'Jun',
#  'Jul',
#  'Aug',
#  'Sept',
#  'Oct',
#  'Nov',
#  'Dec']

# %%
plt.bar(y1,x1)
plt.xlabel('Month')
plt.ylabel('Number of infected people')
plt.show()

# %%
new_data.loc[:,'Jan':'Dec'].describe()
# Out:
#              Jan        Feb        Mar        Apr        May        Jun  \
# count  77.000000  77.000000  77.000000  77.000000  77.000000  77.000000
# mean    0.142857   0.038961   0.194805   0.233766   0.324675   1.207792
# std     0.420347   0.194771   0.858992   0.666809   0.865137   3.931444
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 50%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 75%     0.000000   0.000000   0.000000   0.000000   0.000000   1.000000
# max     2.000000   1.000000   7.000000   4.000000   6.000000  32.000000
#
#               Jul          Aug         Sept          Oct         Nov  \
# count   77.000000    77.000000    77.000000    77.000000   77.000000
# mean     9.350649    48.155844   357.519481   232.324675   55.714286
# std     30.038469   199.277977  1340.169762   667.530158  152.060485
# ...

# %%
map_data=pd.read_json('map_data.json')
map_data
# Out:
#     district  longitude  latitude
# 0  KATHMANDU    85.3045   27.7172
# 1   LALITPUR    85.3176   27.6679
# 2  BHAKTAPUR    85.4280   27.6717
# 3  MAKWANPUR    85.2014   27.4869
# 4   CHITAWAN    84.2555   27.6190
# 5       DANG    82.3915   28.1167
# 6    DHADING    84.9582   27.9779

# %%
import folium

# %%
locations = map_data[['latitude', 'longitude']]
districts = locations.values.tolist()
districts
# Out:
# [[27.7172, 85.3045],
#  [27.6679, 85.3176],
#  [27.6717, 85.428],
#  [27.4869, 85.2014],
#  [27.619, 84.2555],
#  [28.1167, 82.3915],
#  [27.9779, 84.9582]]

# %%
map = folium.Map(location=[27.7172, 85.3045], tiles='Stamen Toner', zoom_start=100)
for point in range(0, len(districts)):
    folium.CircleMarker(districts[point], radius=8, color='red', fill=True, fill_color='red', opacity = 0.4).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
