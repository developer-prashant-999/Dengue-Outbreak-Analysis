# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
new_data = pd.read_csv('data.csv')

# %%
new_data
# Out:
#     Province      Districts  Jan  Feb  Mar  Apr  May  Jun  Jul   Aug  Sept  \
# 0          3  306 KATHMANDU    0    0    0    0    1    1   35   727  9891
# 1          3   308 LALITPUR    0    0    0    0    0    1   99  1558  6016
# 2          3  307 BHAKTAPUR    0    0    0    0    0    0    6    86  1151
# 3          3  312 MAKWANPUR    0    0    0    0    0    0  221   337  2452
# 4          3   313 CHITAWAN    0    0    0    0    0    3    4    24   995
# ..       ...            ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 72         6       602 MUGU    0    0    0    0    0    0    0     1     7
# 73         3     303 RASUWA    0    0    0    0    0    0    0     0     6
# 74         4    403 MUSTANG    0    0    0    0    0    0    0     0     2
# 75         6      601 DOLPA    0    0    0    0    0    0    0     1     1
# 76         6      603 HUMLA    0    0    0    0    0    0    0     0     2
#
#      Oct  Nov  Dec  GrandTotal
# 0   2911  761   49       14376
# 1   1809  120   11        9614
# 2   4204  677   21        6145
# 3   2220  590   17        5837
# 4   1509  638   40        3213
# ..   ...  ...  ...         ...
# 72     4    0    0          12
# 73     5    0    0          11
# 74     6    0    0           8
# 75     2    1    0           5
# 76     1    0    0           3
#
# [77 rows x 15 columns]

# %%
def remove_int(x):
    return ''.join(filter(str.isalpha, x))

# %%
new_data['Districts']=new_data['Districts'].apply(remove_int)

# %%
new_data['Districts']
# Out:
# 0     KATHMANDU
# 1      LALITPUR
# 2     BHAKTAPUR
# 3     MAKWANPUR
# 4      CHITAWAN
#         ...
# 72         MUGU
# 73       RASUWA
# 74      MUSTANG
# 75        DOLPA
# 76        HUMLA
# Name: Districts, Length: 77, dtype: object

# %%
new_data.head()
# Out:
#    Province  Districts  Jan  Feb  Mar  Apr  May  Jun  Jul   Aug  Sept   Oct  \
# 0         3  KATHMANDU    0    0    0    0    1    1   35   727  9891  2911
# 1         3   LALITPUR    0    0    0    0    0    1   99  1558  6016  1809
# 2         3  BHAKTAPUR    0    0    0    0    0    0    6    86  1151  4204
# 3         3  MAKWANPUR    0    0    0    0    0    0  221   337  2452  2220
# 4         3   CHITAWAN    0    0    0    0    0    3    4    24   995  1509
#
#    Nov  Dec  GrandTotal
# 0  761   49       14376
# 1  120   11        9614
# 2  677   21        6145
# 3  590   17        5837
# 4  638   40        3213

# %%
x=new_data['Districts'].tolist()
x
# Out:
# ['KATHMANDU',
#  'LALITPUR',
#  'BHAKTAPUR',
#  'MAKWANPUR',
#  'CHITAWAN',
#  'DANG',
#  'DHADING',
#  'RUPANDEHI',
#  'KAVREPALANCHOK',
#  'SURKHET',
#  'KAILALI',
#  'SUNSARI',
#  'TANAHU',
#  'DARCHULA',
#  'BARA',
#  'SANKHUWASABHA',
#  'GULMI',
#  'GORKHA',
#  'KHOTANG',
#  'PARBAT',
#  'NUWAKOT',
#  'KANCHANPUR',
#  'KASKI',
#  'JHAPA',
#  'RAMECHHAP',
#  'SINDHUPALCHOK',
#  'SYANGJA',
#  'BARDIYA',
#  'PARSA',
#  'PALPA',
#  'BAGLUNG',
#  'MORANG',
#  'NAWALPARASIEAST',
#  'TERHATHUM',
#  'SINDHULI',
#  'ARGHAKHANCHI',
#  'BANKE',
#  'SARLAHI',
#  'UDAYAPUR',
#  'DHANKUTA',
#  'RAUTAHAT',
#  'KAPILBASTU',
#  'NAWALPARASIWEST',
#  'ILAM',
#  'BHOJPUR',
#  'DOLAKHA',
#  'LAMJUNG',
#  'DOTI',
#  'PANCHTHAR',
#  'BAITADI',
#  'MYAGDI',
#  'MAHOTTARI',
#  'OKHALDHUNGA',
#  'PYUTHAN',
#  'RUKUMWEST',
#  'SAPTARI',
#  'DADELDHURA',
#  'ACHHAM',
#  'DHANUSA',
#  'SALYAN',
#  'SIRAHA',
#  'DAILEKH',
#  'BAJHANG',
#  'JUMLA',
#  'KALIKOT',
#  'RUKUMEAST',
#  'SOLUKHUMBU',
#  'BAJURA',
#  'ROLPA',
#  'TAPLEJUNG',
#  'JAJARKOT',
#  'MANANG',
#  'MUGU',
#  'RASUWA',
#  'MUSTANG',
#  'DOLPA',
#  'HUMLA']

# %%
y= [y for y in new_data['GrandTotal'].tolist() if y >= 1682]
temp=[y for y in new_data['GrandTotal'].tolist() if y < 1682]
y.append(sum(temp))
x = new_data.loc[new_data['GrandTotal'].isin(y)]['Districts'].tolist()
x.append('Others')

# %%
x
# Out:
# ['KATHMANDU',
#  'LALITPUR',
#  'BHAKTAPUR',
#  'MAKWANPUR',
#  'CHITAWAN',
#  'DANG',
#  'DHADING',
#  'Others']

# %%
new_data.loc[new_data['Districts'].isin(x)]['Province'].tolist()
# Out:
# [3, 3, 3, 3, 3, 5, 3]

# %%
plt.pie(y,labels=x)
plt.show()

# %%
x1=new_data.loc[:,'Jan':'Dec'].sum().tolist()
x1
# Out:
# [11, 3, 15, 18, 25, 93, 720, 3708, 27529, 17889, 4290, 483]

# %%
y1=list(new_data.columns)[2:-1]
y1
# Out:
# ['Jan',
#  'Feb',
#  'Mar',
#  'Apr',
#  'May',
#  'Jun',
#  'Jul',
#  'Aug',
#  'Sept',
#  'Oct',
#  'Nov',
#  'Dec']

# %%
plt.bar(y1,x1)
plt.xlabel('Month')
plt.ylabel('Number of infected people')
plt.show()

# %%
new_data.loc[:,'Jan':'Dec'].describe()
# Out:
#              Jan        Feb        Mar        Apr        May        Jun  \
# count  77.000000  77.000000  77.000000  77.000000  77.000000  77.000000
# mean    0.142857   0.038961   0.194805   0.233766   0.324675   1.207792
# std     0.420347   0.194771   0.858992   0.666809   0.865137   3.931444
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 50%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 75%     0.000000   0.000000   0.000000   0.000000   0.000000   1.000000
# max     2.000000   1.000000   7.000000   4.000000   6.000000  32.000000
#
#               Jul          Aug         Sept          Oct         Nov  \
# count   77.000000    77.000000    77.000000    77.000000   77.000000
# mean     9.350649    48.155844   357.519481   232.324675   55.714286
# std     30.038469   199.277977  1340.169762   667.530158  152.060485
# min      0.000000     0.000000     1.000000     0.000000    0.000000
# 25%      0.000000     2.000000    23.000000     7.000000    3.000000
# 50%      2.000000     5.000000    54.000000    37.000000   12.000000
# 75%      5.000000    14.000000    87.000000   105.000000   30.000000
# max    221.000000  1558.000000  9891.000000  4204.000000  761.000000
#
#              Dec
# count  77.000000
# mean    6.272727
# std     9.824294
# min     0.000000
# 25%     0.000000
# 50%     2.000000
# 75%     9.000000
# max    49.000000

# %%
map_data=pd.read_json('map_data.json')
map_data
# Out:
#     district  longitude  latitude
# 0  KATHMANDU    85.3045   27.7172
# 1   LALITPUR    85.3176   27.6679
# 2  BHAKTAPUR    85.4280   27.6717
# 3  MAKWANPUR    85.2014   27.4869
# 4   CHITAWAN    84.2555   27.6190
# 5       DANG    82.3915   28.1167
# 6    DHADING    84.9582   27.9779

# %%
import folium

# %%
locations = map_data[['latitude', 'longitude']]
districts = locations.values.tolist()
districts
# Out:
# [[27.7172, 85.3045],
#  [27.6679, 85.3176],
#  [27.6717, 85.428],
#  [27.4869, 85.2014],
#  [27.619, 84.2555],
#  [28.1167, 82.3915],
#  [27.9779, 84.9582]]

# %%
map = folium.Map(location=[27.7172, 85.3045], tiles='Stamen Toner', zoom_start=100)
for point in range(0, len(districts)):
    folium.CircleMarker(districts[point], radius=8, color='red', fill=True, fill_color='red', opacity = 0.4).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b56d6506f81669c7f6bcd5ba0a122d1b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b56d6506f81669c7f6bcd5ba0a122d1b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b56d6506f81669c7f6bcd5ba0a122d1b = L.map(
#                 &quot;map_b56d6506f81669c7f6bcd5ba0a122d1b&quot;,
#                 {
#                     center: [27.7172, 85.3045],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 100,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f76f7f068c638669e66fedd202a51eda = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b56d6506f81669c7f6bcd5ba0a122d1b);
#
#
#             var circle_marker_188ed6148ef13af187ef688887104f5b = L.circleMarker(
#                 [27.7172, 85.3045],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.4, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b56d6506f81669c7f6bcd5ba0a122d1b);
#
#
#             var circle_marker_e89a98f9b8fa0514c509de7b654f16f3 = L.circleMarker(
#                 [27.6679, 85.3176],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.4, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b56d6506f81669c7f6bcd5ba0a122d1b);
#
#
#             var circle_marker_4a2a51415b4561caf54d126ef19034be = L.circleMarker(
#                 [27.6717, 85.428],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.4, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b56d6506f81669c7f6bcd5ba0a122d1b);
#
#
#             var circle_marker_caa2e13b7e4a92bba7a10dab91be596f = L.circleMarker(
#                 [27.4869, 85.2014],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.4, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b56d6506f81669c7f6bcd5ba0a122d1b);
#
#
#             var circle_marker_f52307f51a8c606d1bc78a102a296059 = L.circleMarker(
#                 [27.619, 84.2555],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.4, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b56d6506f81669c7f6bcd5ba0a122d1b);
#
#
#             var circle_marker_af7a2a1b085ba005c0b0138ddf84655f = L.circleMarker(
#                 [28.1167, 82.3915],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.4, &quot;radius&quot;: 8, &q
